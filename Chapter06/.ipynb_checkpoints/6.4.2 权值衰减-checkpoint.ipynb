# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（权值衰减）的设定 =======================
#weight_decay_lambda = 0 # 不使用权值衰减的情况
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.绘制图形==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.08666666666666667, test acc:0.0915
# epoch:1, train acc:0.12666666666666668, test acc:0.1107
# epoch:2, train acc:0.15, test acc:0.1271
# epoch:3, train acc:0.18, test acc:0.1444
# epoch:4, train acc:0.22, test acc:0.1556
# epoch:5, train acc:0.25, test acc:0.1729
# epoch:6, train acc:0.25666666666666665, test acc:0.1807
# epoch:7, train acc:0.29333333333333333, test acc:0.2062
# epoch:8, train acc:0.31333333333333335, test acc:0.2182
# epoch:9, train acc:0.31, test acc:0.2246
# epoch:10, train acc:0.32, test acc:0.2362
# epoch:11, train acc:0.33666666666666667, test acc:0.2462
# epoch:12, train acc:0.3466666666666667, test acc:0.2544
# epoch:13, train acc:0.35333333333333333, test acc:0.2606
# epoch:14, train acc:0.37, test acc:0.266
# epoch:15, train acc:0.38333333333333336, test acc:0.2748
# epoch:16, train acc:0.4, test acc:0.2801
# epoch:17, train acc:0.41, test acc:0.2866
# epoch:18, train acc:0.42, test acc:0.2881
# epoch:19, train acc:0.4033333333333333, test acc:0.2903
# epoch:20, train acc:0.4066666666666667, test acc:0.295
# epoch:21, train acc:0.39666666666666667, test acc:0.301
# epoch:22, train acc:0.4, test acc:0.3123
# epoch:23, train acc:0.42333333333333334, test acc:0.3245
# epoch:24, train acc:0.43, test acc:0.3247
# epoch:25, train acc:0.43, test acc:0.329
# epoch:26, train acc:0.44666666666666666, test acc:0.3481
# epoch:27, train acc:0.4533333333333333, test acc:0.355
# epoch:28, train acc:0.46, test acc:0.3595
# epoch:29, train acc:0.47333333333333333, test acc:0.3654
# epoch:30, train acc:0.5, test acc:0.3735
# epoch:31, train acc:0.5033333333333333, test acc:0.379
# epoch:32, train acc:0.5133333333333333, test acc:0.391
# epoch:33, train acc:0.5166666666666667, test acc:0.3945
# epoch:34, train acc:0.5133333333333333, test acc:0.3989
# epoch:35, train acc:0.5033333333333333, test acc:0.3955
# epoch:36, train acc:0.51, test acc:0.4052
# epoch:37, train acc:0.5233333333333333, test acc:0.4088
# epoch:38, train acc:0.5233333333333333, test acc:0.4147
# epoch:39, train acc:0.5633333333333334, test acc:0.4307
# epoch:40, train acc:0.5833333333333334, test acc:0.4427
# epoch:41, train acc:0.5933333333333334, test acc:0.4455
# epoch:42, train acc:0.5766666666666667, test acc:0.4441
# epoch:43, train acc:0.6533333333333333, test acc:0.4718
# epoch:44, train acc:0.6266666666666667, test acc:0.48
# epoch:45, train acc:0.6133333333333333, test acc:0.4788
# epoch:46, train acc:0.6333333333333333, test acc:0.4883
# epoch:47, train acc:0.6133333333333333, test acc:0.4826
# epoch:48, train acc:0.6533333333333333, test acc:0.4902
# epoch:49, train acc:0.6833333333333333, test acc:0.5178
# epoch:50, train acc:0.6733333333333333, test acc:0.5299
# epoch:51, train acc:0.6933333333333334, test acc:0.5248
# epoch:52, train acc:0.6666666666666666, test acc:0.5358
# epoch:53, train acc:0.6633333333333333, test acc:0.5391
# epoch:54, train acc:0.6733333333333333, test acc:0.5399
# epoch:55, train acc:0.66, test acc:0.537
# epoch:56, train acc:0.6666666666666666, test acc:0.5498
# epoch:57, train acc:0.69, test acc:0.5629
# epoch:58, train acc:0.73, test acc:0.5694
# epoch:59, train acc:0.7033333333333334, test acc:0.571
# epoch:60, train acc:0.7233333333333334, test acc:0.5789
# epoch:61, train acc:0.7266666666666667, test acc:0.5782
# epoch:62, train acc:0.74, test acc:0.577
# epoch:63, train acc:0.75, test acc:0.5774
# epoch:64, train acc:0.7566666666666667, test acc:0.5822
# epoch:65, train acc:0.7433333333333333, test acc:0.5856
# epoch:66, train acc:0.76, test acc:0.5886
# epoch:67, train acc:0.75, test acc:0.5836
# epoch:68, train acc:0.7566666666666667, test acc:0.5877
# epoch:69, train acc:0.75, test acc:0.587
# epoch:70, train acc:0.7566666666666667, test acc:0.5949
# epoch:71, train acc:0.76, test acc:0.6025
# epoch:72, train acc:0.78, test acc:0.6007
# epoch:73, train acc:0.76, test acc:0.5931
# epoch:74, train acc:0.78, test acc:0.6076
# epoch:75, train acc:0.8066666666666666, test acc:0.617
# epoch:76, train acc:0.7966666666666666, test acc:0.6218
# epoch:77, train acc:0.7833333333333333, test acc:0.6166
# epoch:78, train acc:0.7966666666666666, test acc:0.6184
# epoch:79, train acc:0.7966666666666666, test acc:0.6133
# epoch:80, train acc:0.7933333333333333, test acc:0.6068
# epoch:81, train acc:0.7933333333333333, test acc:0.6185
# epoch:82, train acc:0.8133333333333334, test acc:0.6214
# epoch:83, train acc:0.82, test acc:0.618
# epoch:84, train acc:0.8, test acc:0.6155
# epoch:85, train acc:0.7833333333333333, test acc:0.6084
# epoch:86, train acc:0.8166666666666667, test acc:0.6244
# epoch:87, train acc:0.8166666666666667, test acc:0.6285
# epoch:88, train acc:0.8133333333333334, test acc:0.6345
# epoch:89, train acc:0.8233333333333334, test acc:0.6349
# epoch:90, train acc:0.8133333333333334, test acc:0.6376
# epoch:91, train acc:0.8266666666666667, test acc:0.6489
# epoch:92, train acc:0.8233333333333334, test acc:0.6397
# epoch:93, train acc:0.83, test acc:0.6474
# epoch:94, train acc:0.8433333333333334, test acc:0.6317
# epoch:95, train acc:0.8366666666666667, test acc:0.6371
# epoch:96, train acc:0.8433333333333334, test acc:0.6379
# epoch:97, train acc:0.82, test acc:0.6417
# epoch:98, train acc:0.8433333333333334, test acc:0.6517
# epoch:99, train acc:0.84, test acc:0.654
# epoch:100, train acc:0.8433333333333334, test acc:0.6553
# epoch:101, train acc:0.8466666666666667, test acc:0.6539
# epoch:102, train acc:0.87, test acc:0.6565
# epoch:103, train acc:0.8433333333333334, test acc:0.6514
# epoch:104, train acc:0.86, test acc:0.6639
# epoch:105, train acc:0.85, test acc:0.664
# epoch:106, train acc:0.8333333333333334, test acc:0.6649
# epoch:107, train acc:0.8333333333333334, test acc:0.6405
# epoch:108, train acc:0.85, test acc:0.6586
# epoch:109, train acc:0.8533333333333334, test acc:0.6684
# epoch:110, train acc:0.86, test acc:0.6734
# epoch:111, train acc:0.87, test acc:0.6594
# epoch:112, train acc:0.86, test acc:0.6533
# epoch:113, train acc:0.8666666666666667, test acc:0.6656
# epoch:114, train acc:0.86, test acc:0.6827
# epoch:115, train acc:0.8633333333333333, test acc:0.6694
# epoch:116, train acc:0.87, test acc:0.6682
# epoch:117, train acc:0.87, test acc:0.6758
# epoch:118, train acc:0.86, test acc:0.681
# epoch:119, train acc:0.8766666666666667, test acc:0.6776
# epoch:120, train acc:0.86, test acc:0.6811
# epoch:121, train acc:0.8566666666666667, test acc:0.6736
# epoch:122, train acc:0.8666666666666667, test acc:0.6813
# epoch:123, train acc:0.86, test acc:0.6757
# epoch:124, train acc:0.88, test acc:0.6791
# epoch:125, train acc:0.8733333333333333, test acc:0.6879
# epoch:126, train acc:0.88, test acc:0.681
# epoch:127, train acc:0.86, test acc:0.6798
# epoch:128, train acc:0.8833333333333333, test acc:0.6832
# epoch:129, train acc:0.8766666666666667, test acc:0.6773
# epoch:130, train acc:0.8633333333333333, test acc:0.6808
# epoch:131, train acc:0.87, test acc:0.6758
# epoch:132, train acc:0.8733333333333333, test acc:0.6913
# epoch:133, train acc:0.8666666666666667, test acc:0.6883
# epoch:134, train acc:0.86, test acc:0.6932
# epoch:135, train acc:0.8633333333333333, test acc:0.6807
# epoch:136, train acc:0.86, test acc:0.6952
# epoch:137, train acc:0.8866666666666667, test acc:0.6919
# epoch:138, train acc:0.8633333333333333, test acc:0.6943
# epoch:139, train acc:0.8866666666666667, test acc:0.6925
# epoch:140, train acc:0.8866666666666667, test acc:0.6903
# epoch:141, train acc:0.8833333333333333, test acc:0.6867
# epoch:142, train acc:0.8733333333333333, test acc:0.6936
# epoch:143, train acc:0.8866666666666667, test acc:0.6894
# epoch:144, train acc:0.88, test acc:0.6897
# epoch:145, train acc:0.8833333333333333, test acc:0.6867
# epoch:146, train acc:0.8733333333333333, test acc:0.6921
# epoch:147, train acc:0.8833333333333333, test acc:0.6851
# epoch:148, train acc:0.8633333333333333, test acc:0.6864
# epoch:149, train acc:0.8766666666666667, test acc:0.6794
# epoch:150, train acc:0.8766666666666667, test acc:0.6883
# epoch:151, train acc:0.87, test acc:0.6924
# epoch:152, train acc:0.8733333333333333, test acc:0.6944
# epoch:153, train acc:0.8766666666666667, test acc:0.6925
# epoch:154, train acc:0.87, test acc:0.6841
# epoch:155, train acc:0.8766666666666667, test acc:0.6977
# epoch:156, train acc:0.8766666666666667, test acc:0.6965
# epoch:157, train acc:0.8866666666666667, test acc:0.701
# epoch:158, train acc:0.8666666666666667, test acc:0.6948
# epoch:159, train acc:0.8733333333333333, test acc:0.6876
# epoch:160, train acc:0.8766666666666667, test acc:0.6929
# epoch:161, train acc:0.8633333333333333, test acc:0.6988
# epoch:162, train acc:0.8833333333333333, test acc:0.7032
# epoch:163, train acc:0.89, test acc:0.6973
# epoch:164, train acc:0.8766666666666667, test acc:0.6963
# epoch:165, train acc:0.8766666666666667, test acc:0.6959
# epoch:166, train acc:0.8733333333333333, test acc:0.6987
# epoch:167, train acc:0.8833333333333333, test acc:0.7041
# epoch:168, train acc:0.88, test acc:0.6956
# epoch:169, train acc:0.8833333333333333, test acc:0.686
# epoch:170, train acc:0.8866666666666667, test acc:0.6984
# epoch:171, train acc:0.8766666666666667, test acc:0.6931
# epoch:172, train acc:0.87, test acc:0.6993
# epoch:173, train acc:0.8866666666666667, test acc:0.6966
# epoch:174, train acc:0.8866666666666667, test acc:0.6992
# epoch:175, train acc:0.8833333333333333, test acc:0.6988
# epoch:176, train acc:0.88, test acc:0.7012
# epoch:177, train acc:0.8833333333333333, test acc:0.7035
# epoch:178, train acc:0.88, test acc:0.6985
# epoch:179, train acc:0.8833333333333333, test acc:0.6971
# epoch:180, train acc:0.8766666666666667, test acc:0.6994
# epoch:181, train acc:0.8866666666666667, test acc:0.7033
# epoch:182, train acc:0.89, test acc:0.7062
# epoch:183, train acc:0.8833333333333333, test acc:0.702
# epoch:184, train acc:0.9066666666666666, test acc:0.7023
# epoch:185, train acc:0.8866666666666667, test acc:0.7037
# epoch:186, train acc:0.8833333333333333, test acc:0.7062
# epoch:187, train acc:0.89, test acc:0.7044
# epoch:188, train acc:0.8866666666666667, test acc:0.6999
# epoch:189, train acc:0.8833333333333333, test acc:0.6987
# epoch:190, train acc:0.8966666666666666, test acc:0.7016
# epoch:191, train acc:0.8966666666666666, test acc:0.7028
# epoch:192, train acc:0.8966666666666666, test acc:0.7084
# epoch:193, train acc:0.8933333333333333, test acc:0.7034
# epoch:194, train acc:0.88, test acc:0.6999
# epoch:195, train acc:0.8866666666666667, test acc:0.7043
# epoch:196, train acc:0.9033333333333333, test acc:0.6964
# epoch:197, train acc:0.89, test acc:0.7017
# epoch:198, train acc:0.91, test acc:0.7033
# epoch:199, train acc:0.89, test acc:0.6971
# epoch:200, train acc:0.8833333333333333, test acc:0.7065
